# %% [markdown]
# # Building Naive Bayes Classifier in Python

# %% [markdown]
# ## Import packages

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# ## Import data

# %%
# mount Google Drive files by running the following code
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the data
training = pd.read_csv('/content/drive/My Drive/Python-Examples-Prof. salwani/1. Naïve Bayes /iris_train.csv')
test = pd.read_csv('/content/drive/My Drive/Python-Examples-Prof. salwani/1. Naïve Bayes /iris_test.csv')

# %% [markdown]
# ## Create the X, Y, Training and Test

# %%
xtrain = training.drop('Species', axis=1)
ytrain = training.loc[:, 'Species']
xtest = test.drop('Species', axis=1)
ytest = test.loc[:, 'Species']

# %% [markdown]
# ## Init the Gaussian Classifier

# %%
model = GaussianNB()

# %% [markdown]
# ## Train the model

# %%
model.fit(xtrain, ytrain)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ## Predict Output

# %%
pred = model.predict(xtest)

# %% [markdown]
# ## Plot Confusion Matrix

# %%
mat = confusion_matrix(pred, ytest)
names = np.unique(pred)
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, xticklabels=names, yticklabels=names)
plt.xlabel('Truth')
plt.ylabel('Predicted')
# Out:
# Text(89.18, 0.5, 'Predicted')
